# %%
from galvasr2.align.spark.schemas import ARCHIVE_ORG_SCHEMA
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
from flair.data import Sentence
from flair.models import SequenceTagger
from tqdm import tqdm

spark = SparkSession.builder.appName('CC-BY-license').getOrCreate()
input_catalogue_path = "gs://the-peoples-speech-west-europe/archive_org/Mar_7_2021/EXPANDED_LICENSES_FILTERED_ACCESS.jsonl.gz"
df = spark.read.format('json').schema(ARCHIVE_ORG_SCHEMA).load(input_catalogue_path)
print(df.count())
columns = [df.metadata.identifier, df.metadata.description, df.metadata.subject]
df = df.select(columns)
df = df.na.fill('No info')
df = df.select(F.col("`metadata.identifier`").alias("identifier"), 
               F.col("`metadata.description`").alias("description"),
               F.col("`metadata.subject`").alias("subject"))
df = df.withColumn("subject",F.concat_ws(",",F.col("subject")))
df = df.toPandas()
df.head()
# Out:
# 63627
#                                         identifier  \
# 0           0084_Tomorrow_Always_Comes_20_00_32_00
# 1         00BienvenidoALaRevolucinDeLaImpresinEn3D
# 2  00BienvenidoALaRevolucinDeLaImpresinEn3D_201809
# 3                       02777AOpenApril1213_201403
# 4                       02777AOpenApril1713_201403
#
#                                          description  \
# 0  Promotes Bur-Mil Rayon Fabrics (at great lengt...
# 1                                                 3d
# 2                             3d printing; education
# 3  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<p class="Ms...
# 4  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<p class="Ms...
#
#                                              subject
# 0                                            No info
# 1                                                 3d
# 2                             3d printing; education
# 3  ["open","friday","rhina","rhina valentin","bro...
# 4  ["open wednesday","bronxnet tv","public access...

# %%
df = df.replace(r'\n',' ', regex=True) 
df['description'] = df['description'].str.replace('<[^<]+?>', '')
df['subject'] = df['subject'].str.strip('[]').astype(str)
df = df.replace('"', '', regex=True)
df = df.replace(',', '  ', regex=True)
df.head()
# Out:
#                                         identifier  \
# 0           0084_Tomorrow_Always_Comes_20_00_32_00
# 1         00BienvenidoALaRevolucinDeLaImpresinEn3D
# 2  00BienvenidoALaRevolucinDeLaImpresinEn3D_201809
# 3                       02777AOpenApril1213_201403
# 4                       02777AOpenApril1713_201403
#
#                                          description  \
# 0  Promotes Bur-Mil Rayon Fabrics (at great lengt...
# 1                                                 3d
# 2                             3d printing; education
# 3                     OPEN is shot LIVE from Bron...
# 4                     OPEN is shot LIVE from Bron...
#
#                                              subject
# 0                                            No info
# 1                                                 3d
# 2                             3d printing; education
# 3  open  friday  rhina  rhina valentin  bronx  br...
# 4  open wednesday  bronxnet tv  public access  da...

# %% [markdown]
# ## NER

# %%
# load tagger
tagger = SequenceTagger.load("flair/ner-english-ontonotes-fast")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1331379415.0, style=ProgressStyle(descr…
# 2021-05-31 00:25:52,033 loading file /root/.flair/models/ner-english-ontonotes-fast/0d55dd3b912da9cf26e003035a0c269a0e9ab222f0be1e48a3bbba3a58c0fed0.c9907cd5fde3ce84b71a4172e7ca03841cd81ab71d13eb68aa08b259f57c00b6

# %%
# %%time
ner_entities = {
    'CARDINAL':[],
    'DATE':[],
    'EVENT':[],
    'FAC':[],
    'GPE':[],
    'LANGUAGE':[],
    'LAW':[],
    'LOC':[],
    'MONEY':[],
    'NORP':[],
    'ORDINAL':[],
    'ORG':[],
    'PERCENT':[],
    'PERSON':[],
    'PRODUCT':[],
    'QUANTITY':[],
    'TIME':[],
    'WORK_OF_ART':[]
}
tagger = SequenceTagger.load("flair/ner-english-ontonotes-fast")
def get_top_class(tagger, row):
    try:
        sentence = Sentence(row)
        tagger.predict(sentence)
        for entity in sentence.get_spans('ner'):
            ner_entities[entity.tag].append(entity.text) 
    except:
        return 'problem'
description = df['description'].values
subject = df['subject'].values
# Out:
# 2021-05-31 01:27:18,769 loading file /root/.flair/models/ner-english-ontonotes-fast/0d55dd3b912da9cf26e003035a0c269a0e9ab222f0be1e48a3bbba3a58c0fed0.c9907cd5fde3ce84b71a4172e7ca03841cd81ab71d13eb68aa08b259f57c00b6
# CPU times: user 3.43 s, sys: 561 ms, total: 3.99 s
# Wall time: 4.19 s

# %%
# %%time
subject = df['subject'].values
for i in tqdm(range(df.shape[0])):
    get_top_class(tagger, subject[i])
# Out:
#  14%|█▎        | 8668/63627 [05:32<38:15, 23.94it/s]
# 2021-05-31 01:32:55,647 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▎        | 8672/63627 [05:33<36:13, 25.29it/s]
# 2021-05-31 01:32:55,881 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▎        | 8704/63627 [05:33<20:59, 43.61it/s]
# 2021-05-31 01:32:56,401 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▎        | 8712/63627 [05:33<18:33, 49.33it/s]
# 2021-05-31 01:32:56,552 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:32:56,553 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8788/63627 [05:35<27:30, 33.23it/s]
# 2021-05-31 01:32:58,507 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8841/63627 [05:37<40:13, 22.70it/s]
# 2021-05-31 01:33:00,672 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:00,696 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8864/63627 [05:38<33:40, 27.10it/s]
# 2021-05-31 01:33:01,298 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:01,310 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:01,311 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8872/63627 [05:38<28:09, 32.42it/s]
# 2021-05-31 01:33:01,442 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8877/63627 [05:38<25:19, 36.03it/s]
# 2021-05-31 01:33:01,540 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:01,540 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:01,541 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8913/63627 [05:39<22:57, 39.71it/s]
# 2021-05-31 01:33:02,165 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:02,215 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  14%|█▍        | 8939/63627 [05:39<18:32, 49.14it/s]
# 2021-05-31 01:33:02,678 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  15%|█▍        | 9273/63627 [05:53<45:18, 20.00it/s]
# 2021-05-31 01:33:16,326 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  15%|█▍        | 9279/63627 [05:53<36:18, 24.94it/s]
# 2021-05-31 01:33:16,372 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  15%|█▍        | 9290/63627 [05:53<27:56, 32.42it/s]
# 2021-05-31 01:33:16,498 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  15%|█▍        | 9464/63627 [05:57<15:44, 57.36it/s]
# 2021-05-31 01:33:20,796 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  15%|█▍        | 9470/63627 [05:58<19:44, 45.74it/s]
# 2021-05-31 01:33:20,815 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10145/63627 [06:18<15:53, 56.07it/s]
# 2021-05-31 01:33:41,501 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10151/63627 [06:18<15:43, 56.71it/s]
# 2021-05-31 01:33:41,646 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:41,647 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10160/63627 [06:19<16:08, 55.20it/s]
# 2021-05-31 01:33:41,733 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10166/63627 [06:19<15:48, 56.36it/s]
# 2021-05-31 01:33:41,845 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:41,846 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10172/63627 [06:19<16:30, 53.95it/s]
# 2021-05-31 01:33:41,957 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:41,958 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10178/63627 [06:19<18:53, 47.14it/s]
# 2021-05-31 01:33:42,259 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10183/63627 [06:19<20:38, 43.17it/s]
# 2021-05-31 01:33:42,291 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:42,341 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10297/63627 [06:20<09:44, 91.23it/s]
# 2021-05-31 01:33:43,837 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10307/63627 [06:21<10:21, 85.73it/s]
# 2021-05-31 01:33:43,857 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:43,896 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:43,983 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▌        | 10326/63627 [06:21<10:48, 82.14it/s]
# 2021-05-31 01:33:44,092 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:44,093 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:44,180 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10343/63627 [06:21<21:43, 40.88it/s]
# 2021-05-31 01:33:44,643 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:44,643 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10350/63627 [06:22<23:09, 38.33it/s]
# 2021-05-31 01:33:44,861 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:44,943 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10378/63627 [06:22<22:57, 38.66it/s]
# 2021-05-31 01:33:45,658 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10413/63627 [06:23<33:46, 26.26it/s]
# 2021-05-31 01:33:46,739 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10417/63627 [06:24<33:53, 26.16it/s]
# 2021-05-31 01:33:46,757 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10452/63627 [06:24<17:02, 52.02it/s]
# 2021-05-31 01:33:47,246 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:47,257 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-05-31 01:33:47,258 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  16%|█▋        | 10464/63627 [06:24<14:19, 61.87it/s]
# 2021-05-31 01:33:47,389 Warning: An empty Sentence was created! Are there empty strings in your dataset?
#  38%|███▊      | 24327/63627 [08:56<06:47, 96.52it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd
df_ner = pd.DataFrame.from_dict(ner_entities, orient='index').T
df_ner.head()
# Out:
#   CARDINAL      DATE                    EVENT  \
# 0       78      2013                      WWI
# 1       17  Saturday                World War
# 2       17  Saturday                      WW2
# 3       17      2016  Canton 2016 Sports 2016
# 4       17      2016                   9 / 11
#
#                                     FAC           GPE LANGUAGE  \
# 0              Molokai Molokai Planning        Hawaii  English
# 1  Vermont South Burlington City Center         Rusia  English
# 2                           Parade Snow        Russia  Russian
# 3                  Lanai Lanai Planning      Michigan  Russian
# 4                          Cuban Bridge  Holland City  English
#
#                 LAW         LOC MONEY            NORP ORDINAL  \
# 0  Second Amendment  Maui Water    15         Spanish    44th
# 1              None  Maui Water  None         Spanish   first
# 2              None  Maui Water  None           Farsi    44th
# 3              None  Maui Water  None         Persian     6th
# 4              None  Maui Water  None  Asian American     6th
#
#                     ORG PERCENT                    PERSON          PRODUCT  \
# 0       Revolución Rusa    99 %             amanda holley           Gamera
# 1    Russian Revolution    None                       Jin             Lynx
# 2              Historia    None  Jadoo - Ml Zaheer Raggie        Crusaders
# 3  Holland City Council    None                     Lenin        Crusaders
# 4  Holland City Council    None                     Putin  Jack the Ripper
#
#       QUANTITY     TIME                WORK_OF_ART
# 0      12 mile  tonight  The Preacher One Man Show
# 1  120 seconds  minutes  The Preacher One Man Show
# 2         None     hour  The Preacher One Man Show
# 3         None  24 hour  The Preacher One Man Show
# 4         None  24 hour  The Preacher One Man Show

# %% [markdown]
# ## Count appear words

# %%
from collections import Counter
subject = df['subject'].values
final_count = Counter({'a':0})
for i in tqdm(range(df.shape[0])):
    count_row = (Counter(subject[i].split()))
    final_count = final_count + count_row
final_count
# Out:
# 100%|██████████| 63627/63627 [04:37<00:00, 229.69it/s]
# Counter({'No': 47513,
#          'info': 47511,
#          '3d': 8,
#          'printing;': 1,
#          'education': 40,
#          'open': 13,
#          'friday': 3,
#          'rhina': 4,
#          'valentin': 3,
#          'bronx': 2,
#          'bronxnet': 9,
#          'cablevision': 1,
#          'verizon': 1,
#          'fios': 1,
#          'gail': 1,
#          'digital': 28,
#          'kabuki': 2,
#          'lehman': 1,
#          'college': 37,
#          'art': 31,
#          'wednesday': 5,
#          'tv': 24,
#          'public': 86,
#          'access': 63,
#          'daren': 6,
#          'jaime': 6,
#          'sports': 45,
#          'roundup': 2,
#          'monday': 2,
#          'bronxmedia': 2,
#          'bob': 7,
#          'lee': 4,
#          'dj': 1,
#          'cool': 4,
#          'clyde': 3,
#          'bobbyc': 5,
#          'bobyc': 2,
#          'fitness': 4,
#          'music': 124,
#          'yankees': 1,
#          'baseball': 2,
#          'healthcare': 2,
#          'lifestyle': 2,
#          'business': 7,
#          'performs': 2,
#          'orthopedic': 1,
#          'surgeon': 1,
#          'singer': 2,
#          'songwriter': 1,
#          'amanda': 4,
#          'holley': 1,
#          'spolight': 4,
#          'arthristisday': 4,
#          'venghazi': 4,
#          'politic': 4,
#          'arts': 19,
#          'performing': 4,
#          'legalcorner': 4,
#          'davidlesch': 4,
#          'law': 6,
#          'harassment': 4,
#          'health': 87,
#          '2013': 751,
#          'Saturday': 3,
#          'Matinee': 3,
#          'Movies': 6,
#          'Old': 18,
#          'Hawaii': 1,
#          'Farmers': 53,
#          'HFUU': 1,
#          'Candidate': 8,
#          'Forum': 37,
#          'Jin': 1,
#          'and': 1540,
#          'Jadoo': 1,
#          '-': 687,
#          'Ml': 1,
#          'Zaheer': 1,
#          'Raggie': 1,
#          'Revolución': 4,
#          'Rusa;': 1,
#          'Russian': 9,
#          'Revolution;': 2,
#          'Русская': 1,
#          'Революция;': 1,
#          'Historia;': 3,
#          'History;': 3,
#          'История;': 1,
#          'Lenin;': 1,
#          'Putin;': 1,
#          'Rusia;': 1,
#          'Russia;': 1,
#          'Россия;': 1,
#          'Peter': 11,
#          'Kenez': 1,
#          'Michigan': 937,
#          'Holland': 2051,
#          'City': 1423,
#          'of': 1486,
#          'Government': 3928,
#          'Access': 5335,
#          'TV': 7174,
#          'Community': 9191,
#          'Media': 7499,
#          'PEG': 4922,
#          'Vimeo': 4017,
#          '2016': 496,
#          'Meeting': 1260,
#          'Council': 616,
#          '2017': 592,
#          '2018': 659,
#          '2015': 1312,
#          '2014': 876,
#          '78': 1,
#          'Minnesota': 678,
#          'Saint': 936,
#          'Paul': 1081,
#          'Neighborhood': 485,
#          'Network': 648,
#          'SPNN': 465,
#          'Public': 3271,
#          'Youtube': 897,
#          'Budget': 114,
#          '(Website': 5,
#          'Category)': 7,
#          'Politics': 75,
#          '(TV': 90,
#          'Genre)': 85,
#          'minnesota': 103,
#          'budget': 9,
#          'politics': 48,
#          'urban': 4,
#          'black': 32,
#          'african': 12,
#          'american': 16,
#          'minneapolis': 40,
#          'saint': 92,
#          'paul': 165,
#          'Network)': 23,
#          'priorities': 2,
#          'Black': 25,
#          '(Ethnicity)': 39,
#          'خواطر': 1,
#          'أحمد': 1,
#          'الشقيري': 1,
#          '02035': 186,
#          'Vermont': 1686,
#          'Burlington': 651,
#          'CHANNEL': 471,
#          '17': 481,
#          'TOWN': 471,
#          'MEETING': 471,
#          'CCTV17': 471,
#          'Essex': 59,
#          'Junction': 24,
#          'Trustees': 8,
#          'Telecom': 7,
#          'Advisory': 27,
#          'Board': 474,
#          'BTAB': 1,
#          'Town': 141,
#          'Planning': 487,
#          'Commission': 568,
#          'VT': 49,
#          'Selectboard': 409,
#          'South': 52,
#          'Winooski': 85,
#          'Williston': 36,
#          'Joint': 15,
#          'Manager': 2,
#          'Development': 112,
#          'Review': 91,
#          'Burliington': 1,
#          'BurlingtonTelecom': 1,
#          'BT': 3,
#          'Sale': 1,
#          'farmers': 49,
#          'farming': 41,
#          'immigrants': 7,
#          'minorities': 5,
#          'diversity': 1,
#          'immigrant': 7,
#          'minority': 6,
#          'people': 4,
#          'color': 3,
#          'conference': 16,
#          'midwest': 2,
#          'Open': 19,
#          'Cape': 3,
#          'Mass': 6,
#          'Maritime': 1,
#          'Academy': 7,
#          'Cod': 1,
#          'Village': 6,
#          'Social': 112,
#          'issues:': 11,
#          '1950s;Social': 1,
#          'services': 5,
#          'barack': 3,
#          'obama': 7,
#          'white': 10,
#          'house': 17,
#          'youtube': 23,
#          '44th': 3,
#          'president': 6,
#          'Maui': 1067,
#          'County': 614,
#          'Special': 31,
#          'Policy': 40,
#          'Committee': 2099,
#          'Economic': 46,
#          'Agriculture': 32,
#          'Recreation': 29,
#          'Finance': 92,
#          'Water': 104,
#          'Akaku': 5,
#          'Housing': 30,
#          'Transportation': 118,
#          'Regular': 14,
#          'Whole': 5,
#          'CountyCouncil': 1,
#          'Infrastructure': 23,
#          'Environment': 24,
#          'Energy': 271,
#          'Land': 23,
#          'Use': 6,
#          'FInance': 1,
#          'Boards': 34,
#          'Mau': 1,
#          'Intergovernmental': 28,
#          'maui': 55,
#          'Motion': 112,
#          'pictures:': 69,
#          'Projection': 7,
#          'boards': 49,
#          'commission': 79,
#          'Fire': 26,
#          'Safety': 30,
#          'Police': 56,
#          'Cost': 12,
#          'Molokai': 47,
#          'Commissions': 17,
#          'planning': 69,
#          'Lanai': 5,
#          'Cultural': 24,
#          'Costs': 3,
#          'Culture': 120,
#          'Makena': 1,
#          'Resources': 82,
#          'Children': 5,
#          'Youth': 100,
#          'Comissions': 1,
#          'Goverment': 1,
#          'Media:': 25,
#          'Newspapers;Labor:': 1,
#          'Strikes;New': 1,
#          'York': 50,
#          'Comedy': 33,
#          'sci-fi': 6,
#          'detective': 2,
#          'variety': 2,
#          'OTR': 2,
#          'pay': 3,
#          'it': 17,
#          'forward': 1,
#          'silent': 28,
#          'film': 71,
#          'action': 15,
#          'crime': 38,
#          'chase': 1,
#          'scene': 1,
#          'Shanghai': 3,
#          'family': 12,
#          'melodrama': 2,
#          'need': 273,
#          'keyword': 229,
#          'Automobiles:': 33,
#          'Advertising;Advertising:': 2,
#          'Screen': 15,
#          'ads': 9,
#          'Horror': 24,
#          'horror': 34,
#          "60's": 2,
#          'Spanish': 3,
#          'movie': 21,
#          'English': 7,
#          'dubbed': 3,
#          "World's": 35,
#          'Fairs:': 37,
#          'New': 118,
#          '1964': 2,
#          'Birmingham': 2,
#          'Alabama;Houses': 2,
#          'homes:': 11,
#          'Building;Houses': 2,
#          'Sales': 7,
#          "horror70's": 1,
#          'werewolf': 2,
#          'Movie': 29,
#          'McMurray': 1320,
#          'Pennsylvania': 1321,
#          'Peters': 1671,
#          'Township': 1654,
#          'PTCT7': 1321,
#          'commencement': 31,
#          'high': 146,
#          'school': 345,
#          'graduation': 33,
#          'psychotronic;': 2,
#          'vampire;': 5,
#          'Dracula;': 3,
#          'Persia;': 1,
#          'Iran;': 1,
#          'Farsi;': 1,
#          'Persian;': 1,
#          'white;': 1,
#          'Center': 73,
#          'Silent': 8,
#          'Drama': 48,
#          'JED;': 25,
#          'JED.tv;': 25,
#          'JED1230;': 25,
#          'Jim': 37,
#          'Dedelow;': 25,
#          'JEDintheRegion;': 5,
#          'WJOB;': 25,
#          'WJOB1230;': 25,
#          'The': 380,
#          'Preacher': 13,
#          'One': 10,
#          'Man': 13,
#          'Show;': 25,
#          'Horse': 8,
#          'Race;': 4,
#          'PreacherShow': 1,
#          'PreacherShow;': 4,
#          'Region': 4,
#          'Underground': 4,
#          'Belmont': 5755,
#          'High': 159,
#          'School': 384,
#          'Graduations;': 26,
#          'Center;': 2314,
#          'Belmont;': 2327,
#          'Massachusetts;': 2314,
#          '2011;': 29,
#          'Moving': 2320,
#          'Image': 2320,
#          'Archive': 2324,
#          'Department': 5,
#          'Downtown': 16,
#          '2012': 511,
#          'lwvsp': 1,
#          'lwv': 2,
#          '64': 7,
#          'candidate': 5,
#          'forum': 17,
#          'debate': 3,
#          'senate': 3,
#          'River': 9,
#          'Stewards': 1,
#          'MP4': 1,
#          'for': 102,
#          'Dropbox': 1,
#          '2012;': 26,
#          'Foxborough': 3,
#          'Foxboro': 4,
#          'Selectmen': 62,
#          'GRCC': 1,
#          'Art': 62,
#          'Institute': 1,
#          'Henry': 14,
#          'Ford': 5,
#          'College': 18,
#          'Oakland': 6,
#          'University': 15,
#          'Akron': 3,
#          'twin': 33,
#          'cities': 33,
#          'basketball': 3,
#          'showcase': 3,
#          'exhibition': 6,
#          'derek': 34,
#          'reuben': 1,
#          'shoenecker': 1,
#          'arena': 1,
#          'thomas': 10,
#          'spokesman': 1,
#          'recorder': 2,
#          'Festival': 22,
#          'Jazz': 13,
#          'Live': 18,
#          'selby': 3,
#          'avenue': 7,
#          'golden': 7,
#          'thyme': 2,
#          'milton': 3,
#          'jonathan': 3,
#          'wright': 5,
#          'community': 47,
#          'media': 240,
#          'jazz': 36,
#          'festival': 4,
#          'Snow': 6,
#          'Winter': 10,
#          'winter': 13,
#          'carnival': 2,
#          'torchlight': 2,
#          'vulcans': 2,
#          'boreas': 2,
#          'king': 2,
#          'heritage': 6,
#          'cortinas': 1,
#          'hayes': 1,
#          'rice': 3,
#          'park': 16,
#          'landmark': 3,
#          'center': 13,
#          'library': 31,
#          'metropolitan': 5,
#          'state': 30,
#          'university': 14,
#          'Tulip': 87,
#          'Time': 132,
#          '2013;': 85,
#          'BillBakerShow;': 4,
#          'PUC;': 1,
#          'Purdue': 1,
#          'Calumet;': 1,
#          'KeonShow;': 1,
#          'Thomas': 3,
#          'Keon': 1,
#          'TuesdayCallersShow;': 2,
#          'gay': 2,
#          'marriage;': 2,
#          'Indiana': 1,
#          'Legislature': 1,
#          'KusiakShow': 1,
#          'Bill': 24,
#          'Baker;': 4,
#          'Little': 6,
#          'Calumet': 2,
#          'River;': 2,
#          'BillBakerShow': 1,
#          'MondayCallersShow': 1,
#          'Raymundo': 2,
#          'Garcia;': 2,
#          'EAT;': 2,
#          'Hammond': 4,
#          'Indiana;': 2,
#          'RaymundoShow': 1,
#          'FixShow;': 1,
#          'Gary': 17,
#          'Diocese;': 1,
#          'possession;': 1,
#          'exorcism;': 1,
#          'WJOB20140204': 2,
#          'Teamsters': 1,
#          'Local': 4,
#          '142;': 1,
#          'Teamsters;': 1,
#          'Union;': 3,
#          'Teamsters142Show;': 1,
#          'MondayCallersShow;': 2,
#          'WJOB20140210': 1,
#          'WJOB20140210;': 2,
#          'PigattiShow': 1,
#          'PigattiShow;': 1,
#          'WJOB20140217': 1,
#          'Al': 11,
#          'Hamnik;': 2,
#          'NWItimes;': 2,
#          'HamnikShow;': 2,
#          'WJOB20140219': 1,
#          'KusiakShow;': 1,
#          'HuttonShow;': 1,
#          'IHSAA': 1,
#          'Sectionals': 1,
#          '2014;': 219,
#          'WJOB20140304': 1,
#          'Shore;': 2,
#          'WJOB20140310': 2,
#          'WinnersCircleShow;': 1,
#          'Winners': 3,
#          'Circle;': 1,
#          'Will': 7,
#          'Glaros;': 1,
#          'Senator': 7,
#          'Dan': 20,
#          'Coats;': 1,
#          'SenatorCoatsShow;': 1,
#          'WJOB20140317': 2,
#          'RaymundoShow;': 1,
#          'ThursdayCallersShow;': 1,
#          'WJOB20140320': 1,
#          'WJOB20140326': 1,
#          'holland': 257,
#          'fire': 9,
#          'department': 7,
#          'city': 112,
#          'michigan': 139,
#          'Racism': 9,
#          '(Quotation': 16,
#          'Subject)': 44,
#          'culture': 28,
#          'Asian': 2,
#          'American': 45,
#          'African': 17,
#          'Native': 6,
#          'Americans': 14,
#          'In': 65,
#          'United': 18,
#          'States': 8,
#          'metro': 10,
#          'conferences': 1,
#          'Kimberly': 12,
#          'Nightingale': 10,
#          'St': 56,
#          'Almanac': 11,
#          'Massachusetts': 241,
#          'Westwood': 520,
#          'Television': 619,
#          'WestCAT': 230,
#          'Annual': 6,
#          'Tree': 4,
#          'Lighting': 2,
#          'Division': 1,
#          '2': 19,
#          'State': 179,
#          'Hockey': 2,
#          'Final': 1,
#          '(Westwood': 1,
#          'vs.': 50,
#          'Concord-Carlisle)': 1,
#          'Sports': 400,
#          'Summer': 20,
#          'Concert': 68,
#          'Series': 86,
#          'Basketball': 51,
#          '(Interest)': 5,
#          'Security': 85,
#          '(US': 30,
#          'State)': 29,
#          'Group': 4,
#          'Summit': 5,
#          '(Type': 5,
#          'Of': 265,
#          'Conference)': 2,
#          'women': 26,
#          'Conference': 7,
#          'oesw': 3,
#          'America': 27,
#          '(Country)': 4,
#          'wess': 2,
#          'Association': 11,
#          'mayors': 3,
#          'round': 1,
#          'table': 1,
#          'energy': 23,
#          'prize': 2,
#          'Rondo': 1,
#          'Days': 1,
#          '(City/Town/Village)': 56,
#          'neighborhood': 31,
#          'History': 87,
#          'rondo': 3,
#          'Election': 30,
#          '(Appointed': 4,
#          'Role)': 5,
#          'Achievement': 1,
#          'Gap': 1,
#          'spps': 2,
#          'board': 194,
#          'candidates': 22,
#          'election': 27,
#          'schools': 7,
#          'Carnival': 11,
#          '(Recurring': 3,
#          'Event)': 3,
#          'Parade': 5,
#          'network': 33,
#          'foundation': 2,
#          'rosann': 1,
#          'bump': 1,
#          'tom': 6,
#          'lasalle': 1,
#          'first': 8,
#          'bloom': 12,
#          'in': 107,
#          'alla': 2,
#          'dickson': 2,
#          'achievement': 4,
#          'awards': 23,
#          'rev.': 3,
#          'david': 9,
#          'clark': 40,
#          'Dr.': 16,
#          'Melessie': 1,
#          'Clark': 5,
#          'Dawn': 3,
#          'Hennessey': 1,
#          'Rev.': 2,
#          'Patric': 1,
#          'Fowler-Searcy': 1,
#          'LatikaDavis-Jones': 1,
#          'Gagan': 1,
#          'Hunter': 3,
#          'James': 33,
#          'T.': 2,
#          'Johnson': 10,
#          'Jr.': 14,
#          'George': 43,
#          'Spencer': 2,
#          'Connections': 42,
#          'vulcan': 1,
#          'krewe': 1,
#          'overthrow': 1,
#          'Marche': 1,
#          'pour': 2,
#          'le': 1,
#          'climat': 1,
#          'Montbéliard': 1,
#          'manifestation': 2,
#          'protest': 3,
#          'doubs': 1,
#          'france': 5,
#          'réchauffement': 1,
#          'climatique': 1,
#          'savoureuse': 2,
#          'river': 2,
#          'rivière': 2,
#          'belfort': 2,
#          'GoPro': 5,
#          'Hero': 2,
#          '3+': 2,
#          'Business': 132,
#          'BBA': 2,
#          'hearing': 11,
#          'impaired': 1,
#          'accessibility': 1,
#          'source': 1,
#          'kdenlive': 1,
#          'Meroux': 1,
#          'France': 12,
#          'Meroux-Moval': 1,
#          'historical': 4,
#          'reenactments': 1,
#          'reconstitutions': 1,
#          'historiques': 1,
#          'WWI': 2,
#          'World': 96,
#          'War': 220,
#          'I': 46,
#          'première': 1,
#          'guerre': 1,
#          'mondiale': 1,
#          'Belfort': 4,
#          'lights': 1,
#          'lumières': 1,
#          'christmas': 10,
#          'noël': 1,
#          'nuit': 2,
#          'night': 4,
#          'Bavilliers': 2,
#          "c'est": 1,
#          'vous': 1,
#          'élections': 2,
#          'municipales': 2,
#          'élection': 2,
#          'municipale': 2,
#          'Gérald': 1,
#          'Loridat': 1,
#          'Patrouille': 1,
#          'de': 30,
#          'Trévenans': 1,
#          'avions': 1,
#          'planes': 1,
#          'armée': 1,
#          "l'air": 1,
#          'army': 3,
#          'air': 6,
#          'messe': 1,
#          'religion': 4,
#          'chrétien': 1,
#          'chrétienne': 1,
#          'jésus': 2,
#          'christ': 1,
#          'assomption': 1,
#          'vierge': 2,
#          'marie': 2,
#          'sainte': 1,
#          'Builder': 1,
#          'TTU': 1,
#          'Makerspace': 2,
#          'printing': 1,
#          'vœux': 2,
#          '2021': 1,
#          'cérémonie': 1,
#          'ceremony': 2,
#          'brickfilm': 1,
#          'stopmotion': 1,
#          'stop': 7,
#          'motion': 6,
#          'animation': 8,
#          'en': 8,
#          'volume': 2,
#          'block': 4,
#          'tech': 3,
#          'lego': 1,
#          'Grand': 4,
#          'Film': 91,
#          'ltsf': 1,
#          'Fontaine': 3,
#          'Amazon': 1,
#          'Gafamazone': 1,
#          'En': 1,
#          'commun': 1,
#          'Nature': 9,
#          'Environnement': 1,
#          'Les': 1,
#          'Amis': 1,
#          'la': 13,
#          'Terre': 1,
#          'Alternatiba': 1,
#          'tree': 7,
#          'lighting': 5,
#          'town': 205,
#          'hall': 11,
#          'amherst': 7,
#          'massachusetts': 6,
#          'actv': 1,
#          'Mindshift;': 1,
#          'Barbara': 12,
#          'Oakley': 1,
#          'select': 2,
#          'government': 401,
#          'Holocausto;': 2,
#          'Siglo': 1,
#          'XX;': 1,
#          'Educación': 1,
#          'Pueblo': 1,
#          'Judío;': 1,
#          'Havi': 1,
#          'Dreifuss;': 1,
#          'Universidad': 1,
#          'Tel': 1,
#          'Aviv;': 1,
#          'Yad': 1,
#          'Vashem': 1,
#          'Philip': 5,
#          'Zelikow;': 1,
#          'Historia': 3,
#          'Mundial;': 1,
#          'Universal': 7,
#          'SoBu': 1,
#          'Richmond': 1291,
#          'nonprofits': 3,
#          'Neighbor': 4,
#          'Helping': 1,
#          'Huntington': 8,
#          'trailer': 23,
#          'Dean': 3,
#          'Gartlant': 1,
#          'Doug': 1,
#          'Brush': 1,
#          'William': 36,
#          'Richardson': 2,
#          'Mark': 16,
#          'Geppert': 1,
#          'Floretta': 1,
#          'Demus': 1,
#          'Charles': 40,
#          'Upsur': 1,
#          'Char': 1,
#          'Biggs': 1,
#          'truck': 1,
#          'safety': 16,
#          'jaws': 2,
#          'life': 34,
#          'firemen': 1,
#          'fireman': 1,
#          'west': 20,
#          'parade': 11,
#          'Church': 51,
#          'Underhill': 191,
#          'England': 5,
#          'NASA': 26,
#          'drgon': 1,
#          'Darren': 1,
#          'McGavin;Kathie': 1,
#          'Browne;Noah': 1,
#          'Beery': 3,
#          'Jr;': 7,
#          'LQ': 1,
#          'Jones;Lynne': 1,
#          'Marta;Pierre': 1,
#          'Jalbert;Richard': 1,
#          'Petty;William': 1,
#          'Alspaugh;Temi': 1,
#          'Moffit;Joel': 1,
#          'Brown;James': 1,
#          'Morris;Les': 1,
#          'Atkins;Timmy': 1,
#          'Petty;Alan': 1,
#          'Edwards;Hal': 1,
#          'Reed;Blossom': 1,
#          'Terry;': 5,
#          'Tony': 13,
#          'Lorea;Maurice': 1,
#          'Petty;': 1,
#          'Dale': 4,
#          'Inman;': 1,
#          'NASCAR;': 1,
#          'auto': 2,
#          'racing': 4,
#          'dramas;': 64,
#          'war': 33,
#          'WW2;': 17,
#          'all-star': 1,
#          'casts;': 6,
#          'Laurence': 2,
#          'Olivier;': 2,
#          'Glynis': 1,
#          'Johns;': 2,
#          'Leslie': 9,
#          'Howard;': 6,
#          'Raymond': 9,
#          'Massey': 4,
#          'القرآن': 1,
#          'الكريم': 1,
#          'تطور': 1,
#          'الإسلام': 1,
#          'Steger': 1,
#          'Foundation': 22,
#          'MPIRG': 1,
#          'Yea': 1,
#          'MN': 34,
#          'MNYEN': 1,
#          'Abby': 1,
#          'Fenton': 1,
#          'Lobby': 2,
#          'Day': 31,
#          'kollen': 2,
#          'celebration': 2,
#          'freedom': 13,
#          'Appeals': 1,
#          'appeals': 4,
#          'BOA': 1,
#          '02035;': 4,
#          'Lynda': 4,
#          'Walsh;': 5,
#          'Larry': 12,
#          'Harrington;': 3,
#          'DeVellis;': 4,
#          'Lorraine': 5,
#          'Brue;': 4,
#          'Sullivan;': 7,
#          'FCA': 3,
#          'Cable': 25,
#          'Access;': 10,
#          'PEG;': 4,
#          'Foxboro;': 4,
#          'Kevin': 10,
#          'Paicos;': 1,
#          'Billboard;': 1,
#          'Bob': 10,
#          'Kraft': 1,
#          'Ginny': 3,
#          'Coppola;': 5,
#          'Paicos': 3,
#          'Minetest': 1,
#          'Karsthafen': 1,
#          '5th': 3,
#          'Grade': 9,
#          'Boys': 169,
#          'vs': 23,
#          'Bellingham': 3,
#          'January': 42,
#          '3': 10,
#          'Milton': 6,
#          'V': 4,
#          'Walpole': 1,
#          'Jan': 6,
#          '24': 13,
#          'organ': 8,
#          'concert': 26,
#          'heinze': 1,
#          'mi': 10,
#          'Chef': 41,
#          'fredrick': 1,
#          'dehaven': 1,
#          "farmer's": 8,
#          'market': 60,
#          'chef': 14,
#          'series': 22,
#          'pamela': 1,
#          'zinn': 1,
#          'Airline': 1,
#          'industry;Transportation:': 1,
#          'Air;Tourism': 1,
#          '(Media': 5,
#          'ShortFilmFestival': 1,
#          'SummerIn6seconds': 1,
#          '6th': 5,
#          'Girls': 145,
#          'Canton': 7,
#          'North': 14,
#          'Quincy': 2,
#          '15': 13,
#          'pillar': 5,
#          'church': 15,
#          'FCA;': 2,
#          'educational': 2,
#          'resources': 2,
#          'Lincoln': 7,
#          'Illinois': 1,
#          'Primary': 4,
#          'Pillar': 15,
#          'Folkert': 1,
#          'Music': 160,
#          '7th': 1,
#          'boys': 5,
#          'Taunton': 2,
#          '1/31/16': 2,
#          'Organ': 17,
#          'council': 203,
#          'David': 126,
#          'Schout': 1,
#          'Round': 24,
#          'religious': 4,
#          'bicentennial': 2,
#          '8TH': 1,
#          'GRADE': 1,
#          'BOYS': 1,
#          'BASKETBALL': 1,
#          'VS': 1,
#          'ATTLEBORO': 1,
#          'International': 11,
#          'Airport': 4,
#          'Officers': 1,
#          'PACT': 1,
#          'Mayor': 15,
#          'Seth': 1,
#          'Leonard': 2,
#          'Neighborhoods': 2,
#          'Residential': 1,
#          'Construction': 8,
#          'Retail': 6,
#          'Zoning': 16,
#          'Chittenden': 11,
#          'Garcia': 1,
#          'full': 5,
#          'Latino': 5,
#          'Aguilar': 1,
#          'speaker': 2,
#          'CA': 1,
#          'LA': 1,
#          'Research': 6,
#          'glbt': 1,
#          'marketing': 6,
#          'multicultural': 2,
#          'San': 63,
#          'Fransisco': 1,
#          'Morse': 3,
#          'panel': 2,
#          'gitlin': 1,
#          'edited': 1,
#          'saul': 2,
#          '9/11': 9,
#          'hoax': 14,
#          '911': 2,
#          '9-11': 3,
#          'September': 18,
#          '11': 14,
#          '2001': 1,
#          'WTC': 1,
#          'Trade': 4,
#          'Patriot': 1,
#          'Act': 3,
#          'Engineers': 1,
#          'Architects': 1,
#          'truth': 4,
#          'inside': 1,
#          'job': 3,
#          'conspiracy': 4,
#          'theory': 2,
#          'Flight': 2,
#          '93': 1,
#          '77': 1,
#          'fraud': 1,
#          'Municipal': 66,
#          'Meetings': 2,
#          'Sout': 1,
#          'Jericho': 277,
#          'poets': 5,
#          'A': 35,
#          'Entrevista': 1,
#          'Mystery;': 42,
#          'Thriller;': 16,
#          'Murder;': 13,
#          ...})

# %%
dict(sorted(final_count.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'No': 47513,
#  'info': 47511,
#  'Community': 9191,
#  'Media': 7499,
#  'TV': 7174,
#  'Belmont': 5755,
#  'Access': 5335,
#  'PEG': 4922,
#  'Vimeo': 4017,
#  'Government': 3928,
#  'Public': 3271,
#  'Belmont;': 2327,
#  'Archive': 2324,
#  'Moving': 2320,
#  'Image': 2320,
#  'Center;': 2314,
#  'Massachusetts;': 2314,
#  'Committee': 2099,
#  'on': 2079,
#  'Holland': 2051,
#  'U.S.': 1905,
#  'Vermont': 1686,
#  'Peters': 1671,
#  'Township': 1654,
#  'and': 1540,
#  'of': 1486,
#  'City': 1423,
#  'Pennsylvania': 1321,
#  'PTCT7': 1321,
#  'McMurray': 1320,
#  '2015': 1312,
#  'Richmond': 1291,
#  'Meeting': 1260,
#  'Paul': 1081,
#  'Maui': 1067,
#  'Congress;': 941,
#  'Michigan': 937,
#  'Saint': 936,
#  'Youtube': 897,
#  '2014': 876,
#  '2013': 751,
#  '-': 687,
#  'Minnesota': 678,
#  '2018': 659,
#  'Burlington': 651,
#  'Network': 648,
#  'Television': 619,
#  'Council': 616,
#  'County': 614,
#  '2017': 592,
#  'House;': 575,
#  'Commission': 568,
#  'Reform': 553,
#  'Florida': 552,
#  'Sarasota': 551,
#  'Oversight': 550,
#  'the': 543,
#  'Westwood': 520,
#  '2012': 511,
#  '2018;': 508,
#  '2016': 496,
#  'Planning': 487,
#  'Neighborhood': 485,
#  '17': 481,
#  'Board': 474,
#  'CHANNEL': 471,
#  'TOWN': 471,
#  'MEETING': 471,
#  'CCTV17': 471,
#  'SPNN': 465,
#  '2017;': 456,
#  '2016;': 428,
#  'Selectboard': 409,
#  'government': 401,
#  'Sports': 400,
#  'peters': 394,
#  'School': 384,
#  'The': 380,
#  'township': 380,
#  'Floor': 373,
#  'Senate;': 360,
#  'youth': 349,
#  'school': 345,
#  'Varsity': 300,
#  '2015;': 296,
#  'House': 286,
#  'Jericho': 277,
#  'Science': 276,
#  'need': 273,
#  'Energy': 271,
#  'Of': 265,
#  'Presents:': 264,
#  'holland': 257,
#  'BHS': 256,
#  'Report': 250,
#  'Massachusetts': 241,
#  'media': 240,
#  'Services': 239,
#  'WestCAT': 230,
#  'keyword': 229,
#  'War': 220,
#  '2014;': 219,
#  'town': 205,
#  'council': 203,
#  'GTN': 202,
#  'Healthy': 197,
#  'board': 194,
#  'Underhill': 191,
#  '02035': 186,
#  'Lake': 181,
#  'White': 180,
#  'State': 179,
#  'Committee;': 178,
#  'Commerce': 177,
#  'Valley': 176,
#  'Bear': 172,
#  'Production': 172,
#  'Rogue': 172,
#  'Boys': 169,
#  'paul': 165,
#  'Affairs': 164,
#  'Talking': 164,
#  'Jackson': 164,
#  '2019;': 164,
#  'Oregon': 163,
#  'Jefferson': 162,
#  'television': 161,
#  'Music': 160,
#  'High': 159,
#  'RVTV': 157,
#  'Show': 155,
#  'Judiciary': 152,
#  'Senate': 149,
#  'kevin': 148,
#  'II:': 147,
#  'high': 146,
#  'Girls': 145,
#  ';': 144,
#  'ryan': 144,
#  'local': 143,
#  'Education': 142,
#  'Inside': 142,
#  'Town': 141,
#  'Talk': 140,
#  'boni': 140,
#  'bastos': 140,
#  'michigan': 139,
#  'With': 136,
#  'News;': 134,
#  'For': 133,
#  'Time': 132,
#  'Business': 132,
#  'with': 130,
#  'Selectmen;': 130,
#  'Financial': 129,
#  'David': 126,
#  'Library': 126,
#  'music': 124,
#  'Bruce': 124,
#  'schenectady': 124,
#  'Foreign': 123,
#  'Culture': 120,
#  'Technology': 120,
#  'Space': 119,
#  'Transportation': 118,
#  'New': 118,
#  'sulkowski': 115,
#  'Budget': 114,
#  'video': 113,
#  'Arts': 113,
#  'Development': 112,
#  'Social': 112,
#  'Motion': 112,
#  'city': 112,
#  'Pets': 110,
#  'Basketball;': 110,
#  'Armed': 110,
#  'in': 107,
#  'children': 107,
#  'Field': 107,
#  'kids': 106,
#  'Water': 104,
#  'minnesota': 103,
#  'for': 102,
#  'Youth': 100,
#  'books': 100,
#  'Book': 100,
#  'Buzz': 100,
#  'Board;': 99,
#  'activities': 98,
#  'edmund': 97,
#  'justin': 97,
#  'pinto': 97,
#  'World': 96,
#  'Public:': 96,
#  '2019': 94,
#  'saint': 92,
#  'Finance': 92,
#  'Review': 91,
#  'Film': 91,
#  'meeting': 91,
#  '(TV': 90,
#  'Presents;': 90,
#  'And': 89,
#  'health': 87,
#  'Tulip': 87,
#  'History': 87,
#  '2011': 87,
#  'public': 86,
#  'Series': 86,
#  'Genre)': 85,
#  'Winooski': 85,
#  '2013;': 85,
#  'Security': 85,
#  'Natural': 84,
#  'Resources': 82,
#  'Studio': 81,
#  'Warrant': 80,
#  'commission': 79,
#  'Pictures:': 78,
#  'John': 77,
#  'Journal;': 76,
#  'Politics': 75,
#  'Conversations': 74,
#  'Veterans': 74,
#  'Center': 73,
#  'balloon': 72,
#  'Van': 72,
#  'owners': 72,
#  'Owners': 72,
#  'Homeland': 72,
#  'film': 71,
#  'Light': 71,
#  'Recap': 71,
#  'This': 70,
#  'pictures:': 69,
#  'planning': 69,
#  'Bridge': 69,
#  'directors': 69,
#  'Concert': 68,
#  'Cuban': 68,
#  'Schenectady': 68,
#  'twisting;langerman;fewdoit': 67,
#  'Historical': 67,
#  'At': 67,
#  'Municipal': 66,
#  'Roger': 66,
#  'In': 65,
#  'spnn': 65,
#  'Department;': 65,
#  'Reel': 65,
#  'Schenectady;': 65,
#  'Wezel': 65,
#  'dramas;': 64,
#  'Resource': 64,
#  'Senior': 64,
#  'York;': 64,
#  'Select': 64,
#  'access': 63,
#  'San': 63,
#  'Selectmen': 62,
#  'Art': 62,
#  'St.': 62,
#  'Schools': 62,
#  'horror;': 62,
#  'Global': 61,
#  'Meetings;': 61,
#  'Expedition': 61,
#  'Perspective': 61,
#  'market': 60,
#  'Food': 60,
#  'Independence': 60,
#  'Contemporary': 60,
#  'Essex': 59,
#  'history': 59,
#  'Western': 59,
#  'Events;': 59,
#  'Means': 59,
#  'Warming': 59,
#  'comedy': 58,
#  'On': 58,
#  'Maplewood': 58,
#  'Ways': 58,
#  'Health': 57,
#  'Police': 56,
#  'St': 56,
#  '(City/Town/Village)': 56,
#  'maui': 55,
#  'Colton;': 55,
#  'twisting': 54,
#  'Sewer': 54,
#  'erma': 54,
#  'grego': 54,
#  'Government;': 54,
#  'Rules': 54,
#  'Farmers': 53,
#  'to': 53,
#  'Street': 53,
#  'Society': 53,
#  'Workforce': 53,
#  'South': 52,
#  'Market': 52,
#  'Comedy;': 52,
#  'Basketball': 51,
#  'Church': 51,
#  'animal': 51,
#  "What's": 51,
#  'Going': 51,
#  'news': 51,
#  'st': 51,
#  'live': 51,
#  'York': 50,
#  'vs.': 50,
#  'documentary': 50,
#  'Francisco:': 50,
#  'Building': 50,
#  'On?;': 50,
#  'MMU': 50,
#  'Independent': 50,
#  'VT': 49,
#  'farmers': 49,
#  'boards': 49,
#  'Appropriations': 49,
#  'Elections;': 49,
#  'Promo': 49,
#  'politics': 48,
#  'Drama': 48,
#  'Drama;': 48,
#  'Beech': 48,
#  '61': 48,
#  'Molokai': 47,
#  'community': 47,
#  'voice': 47,
#  'Francisco': 47,
#  'drama': 47,
#  'Celebration': 47,
#  'Economic': 46,
#  'I': 46,
#  'Out': 46,
#  'Issues;': 46,
#  "Commissioner's": 46,
#  'Corner': 46,
#  'Administration': 46,
#  'Small': 46,
#  'sports': 45,
#  'American': 45,
#  'Documentary': 45,
#  'Entertainment': 45,
#  'School;': 45,
#  'Subject)': 44,
#  'western': 44,
#  'George': 43,
#  'issues': 43,
#  'Angelo': 43,
#  '16': 43,
#  '&': 43,
#  'Connections': 42,
#  'January': 42,
#  'Mystery;': 42,
#  'teen': 42,
#  'Firenze;': 42,
#  'Women': 42,
#  'meta': 42,
#  'Update': 42,
#  'senior': 42,
#  'DRB': 42,
#  'farming': 41,
#  'Chef': 41,
#  'county': 41,
#  'Crime;': 41,
#  's': 41,
#  'Powers': 41,
#  'education': 40,
#  'minneapolis': 40,
#  'Policy': 40,
#  'clark': 40,
#  'Charles': 40,
#  'Programs;': 40,
#  'Let': 40,
#  'Creative': 40,
#  '(Ethnicity)': 39,
#  'crime': 38,
#  'Service': 38,
#  'culture:': 38,
#  'Park': 38,
#  'college': 37,
#  'Forum': 37,
#  'Fairs:': 37,
#  'Jim': 37,
#  'roles': 37,
#  'Ministries': 37,
#  'otters': 37,
#  'Williston': 36,
#  'jazz': 36,
#  'William': 36,
#  '(Film': 36,
#  'General': 36,
#  'drive': 36,
#  'CESU': 36,
#  'melessie': 36,
#  'highway': 36,
#  'hedges': 36,
#  'Highway': 36,
#  'Hedges': 36,
#  'Outreach': 36,
#  'Believe;': 36,
#  "World's": 35,
#  'A': 35,
#  'comedies;': 35,
#  'Ask': 35,
#  'washington': 35,
#  'pet': 35,
#  'sea': 35,
#  'Spotlight': 35,
#  'spanishrevolution;': 35,
#  'Boards': 34,
#  'horror': 34,
#  'derek': 34,
#  'life': 34,
#  'MN': 34,
#  'food': 34,
#  'BMC': 34,
#  'Communication:': 34,
#  'Joan': 34,
#  'plan': 34,
#  'Comedy': 33,
#  'Automobiles:': 33,
#  'graduation': 33,
#  'twin': 33,
#  'cities': 33,
#  'network': 33,
#  'James': 33,
#  'war': 33,
#  'King': 33,
#  'Football;': 33,
#  'Headlines': 33,
#  'bonner': 33,
#  'Feminism': 33,
#  'Talk;': 33,
#  '3-4-16': 33,
#  'black': 32,
#  'Agriculture': 32,
#  'Occupations:': 32,
#  'soundie': 32,
#  'Rugby;': 32,
#  'movies': 32,
#  'Steal': 32,
#  'PA': 32,
#  'art': 31,
#  'Special': 31,
#  'commencement': 31,
#  'library': 31,
#  'neighborhood': 31,
#  'Day': 31,
#  'fi;': 31,
#  'March': 31,
#  'tr': 31,
#  'adventures;': 31,
#  'poop': 31,
#  'Housing': 30,
#  'Safety': 30,
#  'state': 30,
#  '(US': 30,
#  'Election': 30,
#  'de': 30,
#  'Car': 30,
#  'susan': 30,
#  'a': 30,
#  'zoning': 30,
#  'citizens': 30,
#  'Recreation': 29,
#  'Movie': 29,
#  '2011;': 29,
#  'State)': 29,
#  'Cold': 29,
#  'Robert': 29,
#  'mysteries;': 29,
#  'Advertising': 29,
#  'Horror;': 29,
#  'Free': 29,
#  'headlines': 29,
#  'digital': 28,
#  'Intergovernmental': 28,
#  'silent': 28,
#  'culture': 28,
#  'sci': 28,
#  'Frank': 28,
#  'Atomic-nuclear:': 28,
#  'Task': 28,
#  'Advertising:': 28,
#  'Islam': 28,
#  'sewer': 28,
#  'Advisory': 27,
#  'America': 27,
#  'election': 27,
#  'feature;': 27,
#  'Richard': 27,
#  'Announcement': 27,
#  'Hall': 27,
#  'guidance': 27,
#  'Awards': 27,
#  'development': 27,
#  'Hockey;': 27,
#  'Festival;': 27,
#  'Romance': 27,
#  'Fire': 26,
#  'Graduations;': 26,
#  '2012;': 26,
#  'women': 26,
#  'NASA': 26,
#  'concert': 26,
#  'downtown': 26,
#  'police': 26,
#  'sci-fi;': 26,
#  'Bay': 26,
#  'race': 26,
#  'Vintage': 26,
#  'Life': 26,
#  'time': 26,
#  'Caring': 26,
#  'mystery;': 26,
#  'subtitles': 26,
#  'Black': 25,
#  'Media:': 25,
#  'JED;': 25,
#  'JED.tv;': 25,
#  'JED1230;': 25,
#  'Dedelow;': 25,
#  'WJOB;': 25,
#  'WJOB1230;': 25,
#  'Show;': 25,
#  'Cable': 25,
#  'Civil': 25,
#  '2am': 25,
#  'double': 25,
#  'teens': 25,
#  'June': 25,
#  'guidance:': 25,
#  'john': 25,
#  'Plan': 25,
#  'cable': 25,
#  'Good': 25,
#  'MMCTV': 25,
#  'pets': 25,
#  'in;': 25,
#  'talking': 25,
#  'Remember;': 25,
#  'tv': 24,
#  'Junction': 24,
#  'Environment': 24,
#  'Cultural': 24,
#  'Horror': 24,
#  'Bill': 24,
#  'Round': 24,
#  'murder;': 24,
#  'Pat': 24,
#  'Jack': 24,
#  'MiHolland': 24,
#  'Lecture': 24,
#  'Series;': 24,
#  'District': 24,
#  'Member': 24,
#  'Productions-Single': 24,
#  'Programs/Specials;': 24,
#  'st.': 24,
#  'Peace': 24,
#  'theater': 24,
#  'Network)': 23,
#  'youtube': 23,
#  'Infrastructure': 23,
#  'Land': 23,
#  'energy': 23,
#  'awards': 23,
#  'trailer': 23,
#  'vs': 23,
#  'Tom': 23,
#  'short': 23,
#  'abuse:': 23,
#  'Adventure;': 23,
#  'organic': 23,
#  '2008;': 23,
#  'Force;': 23,
#  '30;': 23,
#  'films': 23,
#  'Postwar': 23,
#  'News': 23,
#  'Payson': 23,
#  'Science;': 23,
#  'theatre': 23,
#  'WBA': 23,
#  'Working': 23,
#  'Festival': 22,
#  'candidates': 22,
#  'Foundation': 22,
#  'series': 22,
#  '*': 22,
#  'Theater;': 22,
#  'Romance;': 22,
#  'Hmong': 22,
#  'tulip': 22,
#  'After': 22,
#  'tutorial;langerman;fewdoit': 22,
#  'westwood': 22,
#  'cheese': 22,
#  '2010;': 22,
#  'Daring': 22,
#  'Dream': 22,
#  'Suzy': 22,
#  'Spivey;': 22,
#  'movie': 21,
#  '(Industry)': 21,
#  'dr.': 21,
#  'Public-access': 21,
#  'Agriculture:': 21,
#  'greg': 21,
#  'Poetry': 21,
#  'science': 21,
#  'summer': 21,
#  'Mystery': 21,
#  "farmers'": 21,
#  'legendado': 21,
#  'Savings': 21,
#  'Dan': 20,
#  'Summer': 20,
#  'west': 20,
#  'Bela': 20,
#  'program': 20,
#  'Industrial': 20,
#  'Anne': 20,
#  'animal;langerman;fewdoit': 20,
#  'tutorials;langerman;fewdoit': 20,
#  'Area:': 20,
#  'film;': 20,
#  'preparation': 20,
#  'Oakdale': 20,
#  "Women's": 20,
#  'February': 20,
#  'Force': 20,
#  'Domain': 20,
#  'Billie': 20,
#  'Money': 20,
#  '2-2-18': 20,
#  '6-1-17': 20,
#  '(Sherif': 20,
#  'arts': 19,
#  'Open': 19,
#  '2': 19,
#  'Aviation:': 19,
#  'Michael': 19,
#  'industry': 19,
#  'agnew': 19,
#  'Roads': 19,
#  'events': 19,
#  'Human': 19,
#  'talk': 19,
#  'poetry': 19,
#  'hanawalt': 19,
#  'romantic': 19,
#  'young': 19,
#  'star': 19,
#  'Legislative': 19,
#  'Make': 19,
#  'Better': 19,
#  'Well-Being': 19,
#  'Lifestyle': 19,
#  'Commons': 19,
#  'venetia': 19,
#  'Gaber)': 19,
#  'Hungry': 19,
#  'Travel;': 19,
#  'Bank': 19,
#  'Mahoney': 19,
#  'Minute;': 19,
#  'Old': 18,
#  'College': 18,
#  'Live': 18,
#  'United': 18,
#  'September': 18,
#  'Ralph': 18,
#  'Ed': 18,
#  'Action': 18,
#  'Rights': 18,
#  'Story': 18,
#  'Design': 18,
#  'Sherlock': 18,
#  '#MiHolland': 18,
#  'use': 18,
#  'WWII;': 18,
#  'League': 18,
#  'December': 18,
#  'October': 18,
#  'Infrastructure:': 18,
#  'Home': 18,
#  'Action;': 18,
#  'student': 18,
#  'Kids': 18,
#  'Video': 18,
#  'students': 18,
#  'People': 18,
#  'Candidates': 18,
#  'show': 18,
#  'Political': 18,
#  'Bicentennial': 18,
#  'water': 18,
#  'Feel': 18,
#  'Bivins;': 18,
#  'Marian': 18,
#  'Event': 18,
#  'Trump': 18,
#  'Beat': 18,
#  'play': 18,
#  'go': 18,
#  'together': 18,
#  'legendas': 18,
#  'Youtube;video;Science': 18,
#  'house': 17,
#  'Commissions': 17,
#  'it': 17,
#  'forum': 17,
#  'Gary': 17,
#  'African': 17,
#  'WW2;': 17,
#  'Organ': 17,
#  'artists': 17,
#  'NOFA': 17,
#  'Air': 17,
#  'Animals:': 17,
#  'Ann': 17,
#  'Sci-Fi': 17,
#  '#hollandmi': 17,
#  'hollandtv': 17,
#  'Naturopath': 17,
#  'Transportation:': 17,
#  'from': 17,
#  'Betty': 17,
#  'Council;': 17,
#  'Voters': 17,
#  '(as': 17,
#  'Edward': 17,
#  'farm': 17,
#  'Western;': 17,
#  'Thriller': 17,
#  'Newsreels': 17,
#  'crime;': 17,
#  'Musical': 17,
#  'Pantry': 17,
#  'Soccer;': 17,
#  'wars': 17,
#  'Issues': 17,
#  'comprehensive': 17,
#  'land': 17,
#  '2022': 17,
#  'volunteers': 17,
#  '1-15-16': 17,
#  'american': 16,
#  'conference': 16,
#  'Downtown': 16,
#  'park': 16,
#  '(Quotation': 16,
#  'Dr.': 16,
#  'Mark': 16,
#  'safety': 16,
#  'Zoning': 16,
#  'Thriller;': 16,
#  'Cinema': 16,
#  'Farm': 16,
#  'programs': 16,
#  'Westminster': 16,
#  'industry:': 16,
#  'empowerment': 16,
#  'Baseball': 16,
#  'Gail': 16,
#  'diet': 16,
#  'Enrichment': 16,
#  'Collaborative;': 16,
#  'J.': 16,
#  'vhs': 16,
#  'love': 16,
#  'commissioner': 16,
#  'Telethons': 16,
#  'PSAs;': 16,
#  '2006;': 16,
#  'service': 16,
#  'letter': 16,
#  'Ryan;': 16,
#  'Amateur': 16,
#  'Visual': 16,
#  'They': 16,
#  'Humble': 16,
#  'Podcast;': 16,
#  'Joint': 15,
#  'action': 15,
#  'Screen': 15,
#  'University': 15,
#  'church': 15,
#  'Pillar': 15,
#  'Mayor': 15,
#  'Margaret': 15,
#  'Lawrence;': 15,
#  'Substance': 15,
#  'westerns;': 15,
#  'B-westerns;': 15,
#  '#holland': 15,
#  'langerman;fewdoit': 15,
#  'Christmas': 15,
#  'To': 15,
#  'November': 15,
#  'MMMUSD': 15,
#  'Scenics:': 15,
#  'Two': 15,
#  'Towns': 15,
#  'smith': 15,
#  'Mary': 15,
#  'Arthur': 15,
#  'Safety:': 15,
#  'Animation': 15,
#  'Dairy': 15,
#  'Friday': 15,
#  'up': 15,
#  'Don': 15,
#  'USA': 15,
#  '1939-40;Amateur': 15,
#  'coaching': 15,
#  'meetings': 15,
#  'water.': 15,
#  'You': 15,
#  'Mental': 15,
#  'Briefing;': 15,
#  '(The': 15,
#  'Masked': 15,
#  'Arab)': 15,
#  'Technology;sexycyborg;shenzhen;China;Maker;Naomi': 15,
#  'Regular': 14,
#  'Henry': 14,
#  'university': 14,
#  'Americans': 14,
#  'Jr.': 14,
#  'chef': 14,
#  'North': 14,
#  'hoax': 14,
#  '11': 14,
#  'Crime': 14,
#  'Bomb': 14,
#  'painting': 14,
#  'Friends': 14,
#  'al': 14,
#  'animals': 14,
#  'whodunits;': 14,
#  '(uncredited)': 14,
#  'naturopath': 14,
#  'pittsburgh': 14,
#  'Homefront;World': 14,
#  'Medicine:': 14,
#  'Baseball;': 14,
#  'Musical;': 14,
#  'Day;': 14,
#  'jungle': 14,
#  'Dave': 14,
#  'Ceremony': 14,
#  'Newsreels;Automobiles:': 14,
#  'Dutch': 14,
#  'Helen': 14,
#  'funny': 14,
#  'district': 14,
#  'Europe': 14,
#  '2007;': 14,
#  'production': 14,
#  'Mantan': 14,
#  'Roy': 14,
#  'set': 14,
#  'lindsey': 14,
#  'Inspirations': 14,
#  'bill': 14,
#  'Ice': 14,
#  'Vincent': 14,
#  'announcement': 14,
#  '10': 14,
#  'rural': 14,
#  'Middlesex': 14,
#  'Attorney': 14,
#  'Armenian': 14,
#  'mandi': 14,
#  'pryor': 14,
#  'stage': 14,
#  'Appeals;': 14,
#  'Brasil': 14,
#  'Ma': 14,
#  'senate.gov;public.resource.org;c-span.org': 14,
#  'open': 13,
#  'Preacher': 13,
#  'Man': 13,
#  'Jazz': 13,
#  'winter': 13,
#  'center': 13,
#  'la': 13,
#  'Tony': 13,
#  'freedom': 13,
#  '24': 13,
#  '15': 13,
#  'Murder;': 13,
#  'Nuclear': 13,
#  'Jean': 13,
#  'Justice': 13,
#  'agriculture': 13,
#  'rights': 13,
#  'Walter': 13,
#  'classes': 13,
#  'Drugs': 13,
#  'Basil': 13,
#  'old': 13,
#  'hospital': 13,
#  'O': 13,
#  'mental': 13,
#  'Railroad': 13,
#  'Animation:': 13,
#  'PTO;': 13,
#  'Things': 13,
#  'animal;balloon': 13,
#  'Girl': 13,
#  'social': 13,
#  '1': 13,
#  'mike': 13,
#  'Sci-Fi;': 13,
#  'Mike': 13,
#  'Others': 13,
#  'Ourselves;': 13,
#  'romance': 13,
#  'sportsmanship': 13,
#  'mcfarlane': 13,
#  'day': 13,
#  'performance': 13,
#  'tapping': 13,
#  'IChallengeU': 13,
#  'facebook': 13,
#  '(voice': 13,
#  'FBE': 13,
#  't': 13,
#  'comédia': 13,
#  '2-3-16': 13,
#  'Pa': 13,
#  'Adoptales;': 13,
#  'african': 12,
#  'Cost': 12,
#  'family': 12,
#  'Kimberly': 12,
#  'bloom': 12,
#  'France': 12,
#  'Barbara': 12,
#  'Larry': 12,
#  'Lugosi;': 12,
#  'Harry': 12,
#  'Dennis': 12,
#  'Holmes': 12,
#  'civil': 12,
#  'green': 12,
#  'Homefront': 12,
#  'Map': 12,
#  'Washington': 12,
#  'guidance;Social': 12,
#  'general': 12,
#  'gene': 12,
#  'Up': 12,
#  'Ceremonies;': 12,
#  'Perception:': 12,
#  'Carol': 12,
#  '4': 12,
#  '19': 12,
#  'Classic': 12,
#  'twisting;balloon': 12,
#  'gorilla': 12,
#  '(Musical': 12,
#  'Films;': 12,
#  'merger': 12,
#  'woc': 12,
#  'world': 12,
#  'Area': 12,
#  'insight': 12,
#  'Dorothy': 12,
#  'movie;': 12,
#  "let's": 12,
#  '--': 12,
#  'Farms': 12,
#  'Marion': 12,
#  'Focus': 12,
#  'Health;': 12,
#  'Audio': 12,
#  'Matters': 12,
#  'new': 12,
#  'Family': 12,
#  'Earth': 12,
#  'cass': 12,
#  'ingram': 12,
#  'Side': 12,
#  'Poets': 12,
#  'Performing': 12,
#  'Spelling': 12,
#  'Bee;': 12,
#  'TODDcast;': 12,
#  'y.e.s.': 12,
#  'Usually': 12,
#  ...}
